# %%
import pandas as pd

# %%
data = pd.read_parquet('dataset.parquet')

# %%
data
# Out:
#       TX_AMOUNT  TX_FRAUD  x_customer_id  y_customer_id  mean_amount  \
# 0         39.30         0      36.491184      26.090450    52.117178
# 1         15.35         0      42.837851      92.315902    14.983996
# 2         23.15         0      77.054406      90.824838    19.283227
# 3         82.58         0      31.019550      51.543309    44.515565
# 4          2.08         0      45.615033      56.843395     6.785031
# ...         ...       ...            ...            ...          ...
# 3864      10.86         0      63.399770      86.728941    94.319920
# 3865      47.46         0      39.622274      16.743582    83.080871
# 3866      79.86         0       5.975792      35.027121    92.375108
# 3867      56.55         0      36.491184      26.090450    52.117178
# 3868     102.45         1      18.713089      90.398395    56.661565
#
#       std_amount  mean_nb_tx_per_day  x_terminal_id  y_terminal_id  \
# 0      26.058589            2.726960      40.813680      23.702698
# ...
